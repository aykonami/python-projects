# %% [markdown]
# <a href="https://colab.research.google.com/github/aykonami/python-projects/blob/main/practice/labs/freecodecamp/discount_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
lab: discount calculator
description: calculates discounted price with input validation
"""

# apply discount function
def apply_discount(price, discount):

    # validate price
    if not isinstance(price, (int, float)):
        return 'The price should be a number'

    # validate discount
    if not isinstance(discount, (int, float)):
        return 'The discount should be a number'

    # ensure valid price
    if price <= 0:
        return 'The price should be greater than 0'

    # ensure valid discount range
    if discount < 0 or discount > 100:
        return 'The discount should be between 0 and 100'

    # calculate final price
    return price - (price * discount / 100)
