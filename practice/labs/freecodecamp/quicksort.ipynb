# %% [markdown]
# <a href="https://colab.research.google.com/github/aykonami/python-projects/blob/main/practice/labs/freecodecamp/quicksort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
lab: quicksort
description: sorts a list using the quicksort algorithm
"""

# quick sort function
def quick_sort(numbers):

    # base case
    if len(numbers) <= 1:
        return numbers

    # choose pivot
    pivot = numbers[0]

    # partition values
    less = [num for num in numbers if num < pivot]
    equal = [num for num in numbers if num == pivot]
    greater = [num for num in numbers if num > pivot]

    # recursively sort partitions
    return quick_sort(less) + equal + quick_sort(greater)
