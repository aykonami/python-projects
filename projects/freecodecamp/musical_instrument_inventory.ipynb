# %% [markdown]
# <a href="https://colab.research.google.com/github/aykonami/python-projects/blob/main/projects/freecodecamp/musical_instrument_inventory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
project: musical instrument class
description: demonstrates object-oriented programming using a musical instrument model
"""

# musical instrument class
class MusicalInstrument:
    def __init__(self, name, instrument_type):
        self.name = name
        self.instrument_type = instrument_type

    def play(self):
        print(f'the {self.name} is fun to play!')

    def get_fact(self):
        return f'the {self.name} is part of the {self.instrument_type} family of instruments.'

# create instruments
instrument_1 = MusicalInstrument('Oboe', 'woodwind')
instrument_2 = MusicalInstrument('Trumpet', 'brass')

# use methods
instrument_1.play()
print(instrument_1.get_fact())

instrument_2.play()
print(instrument_2.get_fact())
# Out:
# the Oboe is fun to play!
# the Oboe is part of the woodwind family of instruments.
# the Trumpet is fun to play!
# the Trumpet is part of the brass family of instruments.
